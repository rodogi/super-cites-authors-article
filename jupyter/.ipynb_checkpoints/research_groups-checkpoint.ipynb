# %%
import pandas as pd
import networkx as nx

# %%
import seaborn as sns; sns.set(style='darkgrid')

# %%
from scipy import stats

# %%
from os.path import join

# %% [markdown]
# # Choose two groups of males and females to compare
#
# An analysis of three decades: 1990--2019
#
#
# We are interested in comparing the topological differences between male and females in two networks:
#
# 1. Co-author network
# 2. Citation network
#
# Two cases: most cited and average cited.

# %%
DATA = "../data/processed/"

# %%
cite = pd.read_csv("../data/processed/cites.csv")

# %%
cite = cite[(cite.t_year >= 1990) & (cite.t_year < 2020)]

# %%
people = pd.read_csv("../data/processed/people.csv")

# %%
cite = pd.merge(cite,
                people.set_index("Short-Id"),
                how='left',
                left_on="target",
                right_index=True)

# %%
cite = pd.merge(cite,
                people.set_index("Short-Id"),
                how="left",
                left_on="source",
                right_index=True,
                suffixes=("_t", "_s"))

# %%
cite_t = cite.groupby('target').size().rename("cites")

# %%
people = pd.merge(people,
                  cite_t,
                  left_on="Short-Id",
                  right_index=True,
                  how="left")

# %%
X_f = people[people.gender=='female'].cites
q1, q2, q3 = X_f.quantile([0.25, 0.5, 0.75])
mu = X_f.mean()
qr = (q3 - q1)
X_f = X_f[(X_f >= q1) & (X_f <= q3)]

# %%
X_f_top = people[people.gender=='female'].cites
X_f_top = X_f_top[(X_f_top > mu + (1.5 * qr))]

# %%
sns.distplot(X_f,
             kde=True);

# %%
sns.distplot(X_f_top,
             kde=True);

# %%
X_f_top.describe()
# Out:
# count     796.000000
# mean      456.131910
# std       569.818547
# min       157.000000
# 25%       200.750000
# 50%       275.000000
# 75%       462.500000
# max      7376.000000
# Name: cites, dtype: float64

# %%
X_f.describe()
# Out:
# count    3778.00000
# mean       21.47406
# std        15.07698
# min         5.00000
# 25%         9.00000
# 50%        17.00000
# 75%        31.00000
# max        60.00000
# Name: cites, dtype: float64
